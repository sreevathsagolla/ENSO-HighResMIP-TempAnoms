# %%
import xarray as xr
import glob
import matplotlib.pyplot as plt
from itertools import product
from tqdm.notebook import tqdm
import numpy as np

# %%
plot_with_spread

# %%
add_colorbar

# %%
format_axis(ax = , kind =
